# %%
from skimage.io import imread,imsave,imshow
# %matplotlib inline

im = imread('watermark.png')
imshow(im)

# %%
from skimage.io import imread,imsave,imshow
# %matplotlib inline

im2 = imread('ex_enhance.jpg')
imshow(im2)

# %%
from skimage.transform import rescale, resize, downscale_local_mean
from skimage.io import imread,imsave,imshow

from matplotlib import pyplot as plt

im = imread('watermark.png')
im_s2 = rescale (im, 0.5, order =0)
print(im_s2.shape)
plt.figure()
imshow(im_s2)
plt.show
# Out:
# (42, 110)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np 
mask = im_s2 <30
print (mask.shape)
print (mask.size)
plt.figure()
imshow(mask)
plt.show
# Out:
# (42, 110)
# 4620
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from PIL import Image
from skimage.io import imread,imsave,imshow
def watermark_picture(input_image_path,output_image_path,watermark_image_path,position):
    base_image = Image.open(input_image_path)
    watermark = Image.open(watermark_image_path)
    # add watermark to your image
    base_image.paste(watermark, position)
    base_image.show()
    base_image.save(output_image_path)
watermark_picture('ex_enhance.jpg', 'ex_enhance2.jpg','watermark.png', (0,0))
imshow(imread('ex_enhance2.jpg'))
plt.title('ex_enhance_watermarkfus.jpg')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from PIL import Image
from skimage.io import imread,imsave,imshow
def watermark_picture(input_image_path,output_image_path,watermark_image_path,position):
    base_image = Image.open(input_image_path)
    watermark = Image.open(watermark_image_path)
    # add watermark to your image
    base_image.paste(watermark, position)
    base_image.show() 
    base_image.save(output_image_path)
watermark_picture('ex_enhance.jpg', 'ex_enhance2.jpg','watermark.png', (500,300))
imshow(imread('ex_enhance2.jpg'))
plt.title('ex_enhance_watermarkfus.jpg')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from PIL import Image
from matplotlib.pyplot import imshow

def watermark_picture(input_image_path,output_image_path,watermark_image_path,position):
    base_image = Image.open(input_image_path)
    watermark = Image.open(watermark_image_path)
    # add watermark to your image
    base_image.paste(watermark, position, watermark)
    base_image.show()
    base_image.save(output_image_path)
    plt.imshow(base_image)

im = Image.open('watermark.png')
im = im.convert("RGBA")
datas = im.getdata()

newData = []
for item in datas:
    if item[0] == 0 and item[1] == 0 and item[2] == 0:
        newData.append((0, 0, 0, 0))
    else:
        if item[0] < 150:
            newData.append((0, 0, 0, 0))
        else:
            newData.append(item)
            #print(item)
            

im.putdata(newData)
im.save("ULB_blanc.png", "PNG")

watermark_picture('ex_enhance.jpg', 'final.jpg', "ULB_blanc.png", (500,300))
plt.title('final.jpg')
# Out:
# Text(0.5, 1.0, 'final.jpg')

# %%
from PIL import Image

def watermark_picture(input_image_path, output_image_path, watermark_image_path, position):
    base_image = Image.open(input_image_path)
    watermark = Image.open(watermark_image_path)
    # add watermark to your image 
    base_image.paste(watermark, position, watermark)
    base_image.show()
    base_image.save(output_image_path)
    plt.imshow(base_image)
    
im = Image.open('watermark.png')

im = im.convert("RGBA")
im.putalpha(128)   #Visibility 128=50%, max 255

datas = im.getdata()

newData = []
for item in datas:
    if item[0] == 0 and item[1] == 0 and item[2] == 0:
        newData.append((0, 0, 0, 0))
    else:
        if item[0] < 150:
            newData.append((0, 0, 0, 0))
        else:
            newData.append(item)
            #print(item)

im.putdata(newData)
im.save("ULB_transparent.png", "PNG")

watermark_picture('ex_enhance.jpg', 'extrapointfinal_transparence.jpg','ULB_transparent.png', (500, 300))
plt.title('extrapointfinal_transparence.jpg')
# Out:
# Text(0.5, 1.0, 'extrapointfinal_transparence.jpg')

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-ddf3ab1a0109> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3
#       4 # Load the image
#       5 im = cv2.imread('extrapointfinal_transparence.jpg',0)
#
# ModuleNotFoundError: No module named 'cv2'
